# %% [markdown]
# # Banc d'oiseaux interactif — démonstration
#
# Ce notebook contient une simulation **2D (projection)** d'un banc d'oiseaux (boids) et une interface interactive :
#
# - Clique dans la figure pour placer une **cible** pour l'oiseau contrôlé.
# - L'oiseau contrôlé reçoit une accélération visant la cible ; les autres boids suivent les règles de Reynolds.
# - poursuite RL :
#     - Un agent qui doit imiter le mouvement des autres oiseaux
#     - multi agents qui doivent lead le groupe pour pouvoir obtenir une forme spécifique.
#
# Objectif : créer un *environnement* interactif prêt à être étendu (Gym env, rendu 3D, ou contrôle par RL).

# %%
# For mouse control 
# %matplotlib qt
from mpl_toolkits.mplot3d import Axes3D

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from mpl_toolkits.mplot3d import proj3d
from boids import Boid, Flock, leader_acceleration
import time
try:
    from scipy.spatial import cKDTree as KDTree
    _KD_AVAILABLE = True
except Exception:
    KDTree = None
    _KD_AVAILABLE = False
    
plt.rcParams['figure.figsize'] = (8,8)

# %%
plt.ion()  # mode interactif

bound_size = 50.0

# --- setup GUI ---
flock = Flock(n=1000, bounds=[bound_size, bound_size, bound_size], seed=2)
flock.boids[0].vel = np.array([1.0, 0.0, 0.3])
# print(flock)
controlled_id = 0
positions, velocities = flock.get_state()
# print(positions.shape)
target = positions[controlled_id].copy()

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlim(-flock.bounds[0], flock.bounds[0])
ax.set_ylim(-flock.bounds[1], flock.bounds[1])
ax.set_zlim(-flock.bounds[2], flock.bounds[2])

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

scat = ax.scatter([], [], [], s=40) # Définition du scatter pour les boids
controlled_sc = ax.scatter([], [], [], s=120, edgecolors='k')
target_sc = ax.scatter([target[0]], [target[1]], s=80, marker='x')
#txt = ax.text(0.02, 0.98, '', transform=ax.transAxes, va='top')

def on_click(event):
    if event.inaxes != ax:
        return

    # coordonnées écran
    x2, y2 = event.x, event.y

    # projection inverse écran -> monde
    inv = ax.transData.inverted()
    xdata, ydata = inv.transform((x2, y2))

    target[0] = xdata
    target[1] = ydata
    # target[2] inchangé (plan XY)

    target_sc._offsets3d = (
        [target[0]],
        [target[1]],
        [target[2]]
    )

    fig.canvas.draw_idle()


fig.canvas.mpl_connect('button_press_event', on_click)

# initialize
positions, _ = flock.get_state()

scat._offsets3d = (
    positions[:, 0],
    positions[:, 1],
    positions[:, 2]
)

controlled_sc._offsets3d = (
    [positions[controlled_id, 0]],
    [positions[controlled_id, 1]],
    [positions[controlled_id, 2]]
)

target_sc._offsets3d = (
    [target[0]],
    [target[1]],
    [target[2]]
)

fig.canvas.draw()
fig.canvas.flush_events()


# --- manual animation loop (robuste) ---
interval = 0.1  # secondes (0.1s)
frame = 0
try:
    while True:

        leader_id = 0
        t = frame * flock.dt

        positions, velocities = flock.get_state()
        leader_pos = positions[leader_id]
        leader_vel = velocities[leader_id]

        leader_acc = leader_acceleration(
            t,
            leader_pos,
            leader_vel,
            flock.max_acc
        )

        # compute action for controlled boid
        positions, velocities = flock.get_state()
        my_pos = positions[controlled_id]
        desired = target - my_pos
        if np.linalg.norm(desired) > 1e-6:
            desired = desired / np.linalg.norm(desired) * flock.max_acc
        else:
            desired = np.zeros(3)
        actions = {controlled_id: desired}
        # print('actions', actions)

        # update physics
        actions[leader_id] = leader_acc

        flock.step(external_actions=actions)

        # update plot
        positions, _ = flock.get_state()
        scat._offsets3d = (
            positions[:, 0],
            positions[:, 1],
            positions[:, 2]
        )

        controlled_sc._offsets3d = (
            [positions[controlled_id, 0]],
            [positions[controlled_id, 1]],
            [positions[controlled_id, 2]]
        )

        target_sc._offsets3d = (
            [target[0]],
            [target[1]],
            [target[2]]
        )

        #txt.set_text(f'Frame: {frame}')
        # force redraw
        fig.canvas.draw()
        fig.canvas.flush_events()

        frame += 1
        time.sleep(interval)  # pause exactly ~interval seconds (can adjust)
except KeyboardInterrupt:
    print("Animation stopped par l'utilisateur (Ctrl-C).")
# Out:
# Animation stopped par l'utilisateur (Ctrl-C).

# %%
plt.close()
